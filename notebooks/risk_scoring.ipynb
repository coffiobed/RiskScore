# %% [markdown]
# # Modélisation du Risque de Crédit - RiskScore
# Ce notebook présente la démarche statistique pour prédire le risque de défaut de paiement.

# %% [markdown]
# ## 1. Importation des librairies et chargement

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %% [markdown]
# ## 2. Traitement des données & Modélisation
# Application d'une régression logistique avec ajustement des poids pour gérer le déséquilibre des classes.

# %%
# Configuration du modèle (Standard de l'industrie bancaire)
model = LogisticRegression(class_weight='balanced', random_state=42)
print("Modèle prêt pour l'entraînement.")
